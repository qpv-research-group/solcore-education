# %% [markdown]
# # Section 8: Textured Si
#
# This example is based on Figures 6, 7 and 8 from [this paper](https://doi.org/10.1364/OE.23.0A1720).
# This compares three different structures, all based on a 200 micron thick slab of silicon
# with different surface textures:
#
# 1. Planar front surface (TMM), crossed grating at rear (RCWA)
# 2. Inverted pyramids on the front surface (RT_Fresnel), planar rear surface (TMM)
# 3. Inverted pyramids on the front surface (RT_Fresnel), crossed grating at rear (RCWA)
#
# The methods which will be used to calculate the redistribution matrices in each case are given in
# brackets. If case 1 and 2 are calculated first, then case 3 does not require the calculations of
# any additional matrices, since it will use the rear matrix from (1) and the front matrix from (2).
#
# ## Setting up
#
# First, importing relevant packages:

# %%
import numpy as np
import os

# solcore imports
from solcore.structure import Layer
from solcore import material
from solcore import si

from rayflare.structure import Interface, BulkLayer, Structure
from rayflare.matrix_formalism import process_structure, calculate_RAT
from rayflare.utilities import get_savepath
from rayflare.transfer_matrix_method import tmm_structure
from rayflare.angles import theta_summary, make_angle_vector
from rayflare.textures import regular_pyramids
from rayflare.options import default_options

from solcore.material_system import create_new_material
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sparse import load_npz

# %% [markdown]
# To make sure we are using the same optical constants for Si, load the same Si n/k data used in the paper
# linked above:

# %%
create_new_material("Si_OPTOS", "data/Si_OPTOS_n.txt", "data/Si_OPTOS_k.txt",
                    overwrite=True)
# Out:
# Material created with optical constants n and k only.

# %% [markdown]
# You only need to do this one time, then the material will be stored in Solcore's material database.
#
# Setting options (taking the default options for everything not specified explicitly):

# %%
angle_degrees_in = 8 # same as in Fraunhofer paper

wavelengths = np.linspace(900, 1200, 20) * 1e-9

Si = material("Si_OPTOS")()
Air = material("Air")()

options = default_options()
options.wavelengths = wavelengths
options.theta_in = angle_degrees_in * np.pi / 180 # incidence angle (polar angle)
options.n_theta_bins = 50
options.c_azimuth = 0.25
options.n_rays = 5e5 # number of rays per wavelength in ray-tracing
options.project_name = "OPTOS_comparison"
options.orders = 60 # number of RCWA orders to use (more = better convergence, but slower)
options.pol = "u" # unpolarized light
options.only_incidence_angle = False

# %% [markdown]
# ## Defining the structures
#
# Now, set up the grating basis vectors for the RCWA calculations and define the grating structure.
# These are squares, rotated by 45 degrees. The halfwidth is calculated based on the area fill factor
# of the etched pillars given in the paper.

# %%
x = 1000

d_vectors = ((x, 0), (0, x))
area_fill_factor = 0.36
hw = np.sqrt(area_fill_factor) * 500

back_materials = [
    Layer(width=si("120nm"), material=Si,
        geometry=[{"type": "rectangle", "mat": Air, "center": (x / 2, x / 2),
                "halfwidths": (hw, hw), "angle": 45}],
    )]

# %% [markdown]
# Now we define the pyramid texture for the front surface in case (2) and (3) and make the four
# possible different surfaces: planar front and rear, front with pyramids, rear with grating.
# We specify the method to use to calculate the redistribution matrices in each case and create
# the bulk layer.

# %%
surf = regular_pyramids(elevation_angle=55, upright=False)

front_surf_pyramids = Interface(
    "RT_Fresnel",
    texture=surf,
    layers=[],
    name="inv_pyramids_front_" + str(options["n_rays"]),
)

front_surf_planar = Interface("TMM", layers=[], name="planar_front")

back_surf_grating = Interface(
    "RCWA",
    layers=back_materials,
    name="crossed_grating_back",
    d_vectors=d_vectors,
    rcwa_orders=20,
)

back_surf_planar = Interface("TMM", layers=[], name="planar_back")

bulk_Si = BulkLayer(200e-6, Si, name="Si_bulk")
# Out:
# fixed h 0.7140740033710572

# %% [markdown]
# Now we create the different structures and 'process' them (this will calculate the relevant
# matrices if necessary, or do nothing if it finds the matrices have previously been calculated and
# the files already exist). We don't need to process the final structure because it will use matrices
# calculated for `SC_fig6` and `SC_fig7`.

# %%
SC_fig6 = Structure(
    [front_surf_planar, bulk_Si, back_surf_grating], incidence=Air, transmission=Air
)
SC_fig7 = Structure(
    [front_surf_pyramids, bulk_Si, back_surf_planar], incidence=Air, transmission=Air
)
SC_fig8 = Structure(
    [front_surf_pyramids, bulk_Si, back_surf_grating], incidence=Air, transmission=Air
)

process_structure(SC_fig6, options, save_location='current')
process_structure(SC_fig7, options, save_location='current')
# Out:
# Making matrix for planar surface using TMM for element 0 in structure
# Existing angular redistribution matrices found
# Existing angular redistribution matrices found
# RCWA calculation for element 2 in structure
# Existing angular redistribution matrices found
# Ray tracing with Fresnel equations for element 0 in structure
# Existing angular redistribution matrices found
# Existing angular redistribution matrices found
# Making matrix for planar surface using TMM for element 2 in structure
# Existing angular redistribution matrices found

# %% [markdown]
# ## Calculating R/A/T
#
# Then we ask RayFlare to calculate the reflection, transmission and absorption through matrix
# multiplication, and get the required result out (absorption in the bulk) for each cell. We
# also load the results from the reference paper to compare them to the ones calculated with RayFlare.

# %%
#| output: false

results_fig6 = calculate_RAT(SC_fig6, options, save_location='current')
results_fig7 = calculate_RAT(SC_fig7, options, save_location='current')
results_fig8 = calculate_RAT(SC_fig8, options, save_location='current')

RAT_fig6 = results_fig6[0]
RAT_fig7 = results_fig7[0]
RAT_fig8 = results_fig8[0]

sim_fig6 = np.loadtxt("data/optos_fig6_sim.csv", delimiter=",")
sim_fig7 = np.loadtxt("data/optos_fig7_sim.csv", delimiter=",")
sim_fig8 = np.loadtxt("data/optos_fig8_sim.csv", delimiter=",")
# Out:
# After iteration 1 : maximum power fraction remaining = 0.30465620023181417
# After iteration 2 : maximum power fraction remaining = 0.2652227087310308
# After iteration 3 : maximum power fraction remaining = 0.24104388325166476
# After iteration 4 : maximum power fraction remaining = 0.22162515027352642
# After iteration 5 : maximum power fraction remaining = 0.20444594182975462
# After iteration 6 : maximum power fraction remaining = 0.1889564644557627
# After iteration 7 : maximum power fraction remaining = 0.1749093089614654
# After iteration 8 : maximum power fraction remaining = 0.16216073861038816
# After iteration 9 : maximum power fraction remaining = 0.15059701585460672
# After iteration 10 : maximum power fraction remaining = 0.14011389944287728
# After iteration 11 : maximum power fraction remaining = 0.13061278773119808
# After iteration 12 : maximum power fraction remaining = 0.122001043579509
# After iteration 13 : maximum power fraction remaining = 0.11419275097227372
# After iteration 14 : maximum power fraction remaining = 0.10710907134010297
# After iteration 15 : maximum power fraction remaining = 0.10067819164202353
# After iteration 16 : maximum power fraction remaining = 0.0948350126459026
# After iteration 17 : maximum power fraction remaining = 0.08952070547055473
# After iteration 18 : maximum power fraction remaining = 0.08468221780012294
# After iteration 19 : maximum power fraction remaining = 0.08027177506263598
# After iteration 20 : maximum power fraction remaining = 0.07624639965483658
# After iteration 21 : maximum power fraction remaining = 0.07256745897724669
# After iteration 22 : maximum power fraction remaining = 0.06920024656626585
# After iteration 23 : maximum power fraction remaining = 0.06611359728877059
# After iteration 24 : maximum power fraction remaining = 0.06327953587745216
# After iteration 25 : maximum power fraction remaining = 0.06067295723635843
# After iteration 26 : maximum power fraction remaining = 0.0582713365357391
# After iteration 27 : maximum power fraction remaining = 0.056054466943202694
# After iteration 28 : maximum power fraction remaining = 0.0540042228014931
# After iteration 29 : maximum power fraction remaining = 0.05210434610601071
# After iteration 30 : maximum power fraction remaining = 0.05034025422506114
# After iteration 31 : maximum power fraction remaining = 0.048698866922600614
# After iteration 32 : maximum power fraction remaining = 0.04716845087394991
# After iteration 33 : maximum power fraction remaining = 0.045738480000969195
# After iteration 34 : maximum power fraction remaining = 0.04439951008884669
# After iteration 35 : maximum power fraction remaining = 0.043143066278275244
# After iteration 36 : maximum power fraction remaining = 0.04196154215209234
# After iteration 37 : maximum power fraction remaining = 0.04084810925313005
# After iteration 38 : maximum power fraction remaining = 0.039796635979422935
# After iteration 39 : maximum power fraction remaining = 0.0388016149038742
# After iteration 40 : maximum power fraction remaining = 0.037858097658101386
# After iteration 41 : maximum power fraction remaining = 0.036961636604787754
# After iteration 42 : maximum power fraction remaining = 0.03610823259988211
# After iteration 43 : maximum power fraction remaining = 0.0352942882159084
# After iteration 44 : maximum power fraction remaining = 0.034516565860986705
# After iteration 45 : maximum power fraction remaining = 0.03377215028544734
# After iteration 46 : maximum power fraction remaining = 0.03305841501964726
# After iteration 47 : maximum power fraction remaining = 0.03237299233325612
# After iteration 48 : maximum power fraction remaining = 0.03171374634832543
# After iteration 49 : maximum power fraction remaining = 0.031078748976309918
# After iteration 50 : maximum power fraction remaining = 0.030466258383272223
# After iteration 51 : maximum power fraction remaining = 0.02987469971812815
# After iteration 52 : maximum power fraction remaining = 0.029302647866313543
# After iteration 53 : maximum power fraction remaining = 0.0287488120159762
# After iteration 54 : maximum power fraction remaining = 0.028212021845992426
# After iteration 55 : maximum power fraction remaining = 0.02769121516502856
# After iteration 56 : maximum power fraction remaining = 0.027185426848738196
# After iteration 57 : maximum power fraction remaining = 0.026693778938213158
# After iteration 58 : maximum power fraction remaining = 0.026215471777174263
# After iteration 59 : maximum power fraction remaining = 0.025749776078265944
# After iteration 60 : maximum power fraction remaining = 0.025296025820357042
# After iteration 61 : maximum power fraction remaining = 0.024853611889086424
# After iteration 62 : maximum power fraction remaining = 0.024421976382147957
# After iteration 63 : maximum power fraction remaining = 0.024000607509097886
# After iteration 64 : maximum power fraction remaining = 0.02358903502288609
# After iteration 65 : maximum power fraction remaining = 0.023186826126953327
# After iteration 66 : maximum power fraction remaining = 0.022793581807677987
# After iteration 67 : maximum power fraction remaining = 0.022408933547272282
# After iteration 68 : maximum power fraction remaining = 0.022032540376983118
# After iteration 69 : maximum power fraction remaining = 0.021664086234706677
# After iteration 70 : maximum power fraction remaining = 0.021303277594929504
# After iteration 71 : maximum power fraction remaining = 0.020949841342310645
# After iteration 72 : maximum power fraction remaining = 0.0206035228632608
# After iteration 73 : maximum power fraction remaining = 0.020264084332593496
# After iteration 74 : maximum power fraction remaining = 0.0199313031747542
# After iteration 75 : maximum power fraction remaining = 0.01960497068130604
# After iteration 76 : maximum power fraction remaining = 0.01928489076829308
# After iteration 77 : maximum power fraction remaining = 0.018970878858837904
# After iteration 78 : maximum power fraction remaining = 0.018662760877881747
# After iteration 79 : maximum power fraction remaining = 0.018360372347361792
# After iteration 80 : maximum power fraction remaining = 0.018063557571359613
# After iteration 81 : maximum power fraction remaining = 0.017772168901861726
# After iteration 82 : maximum power fraction remaining = 0.017486066076763108
# After iteration 83 : maximum power fraction remaining = 0.0172051156226286
# After iteration 84 : maximum power fraction remaining = 0.01692919031551758
# After iteration 85 : maximum power fraction remaining = 0.01665816869388334
# After iteration 86 : maximum power fraction remaining = 0.01639193461818982
# After iteration 87 : maximum power fraction remaining = 0.016130376872452463
# After iteration 88 : maximum power fraction remaining = 0.01587338880341383
# After iteration 89 : maximum power fraction remaining = 0.015620867993515425
# After iteration 90 : maximum power fraction remaining = 0.015372715964229618
# After iteration 91 : maximum power fraction remaining = 0.01512883790667572
# After iteration 92 : maximum power fraction remaining = 0.014889142436765854
# After iteration 93 : maximum power fraction remaining = 0.01465354137241404
# After iteration 94 : maximum power fraction remaining = 0.01442194953059899
# After iteration 95 : maximum power fraction remaining = 0.014194284542301122
# After iteration 96 : maximum power fraction remaining = 0.013970466683539882
# After iteration 97 : maximum power fraction remaining = 0.013750418720921292
# After iteration 98 : maximum power fraction remaining = 0.013534065770270288
# After iteration 99 : maximum power fraction remaining = 0.013321335167069265
# After iteration 100 : maximum power fraction remaining = 0.013112156347556088
# After iteration 101 : maximum power fraction remaining = 0.012906460739452463
# After iteration 102 : maximum power fraction remaining = 0.012704181661398957
# After iteration 103 : maximum power fraction remaining = 0.012505254230267318
# After iteration 104 : maximum power fraction remaining = 0.012309615275605134
# After iteration 105 : maximum power fraction remaining = 0.012117203260543438
# After iteration 106 : maximum power fraction remaining = 0.011927958208565632
# After iteration 107 : maximum power fraction remaining = 0.01174182163559665
# After iteration 108 : maximum power fraction remaining = 0.011558736486925639
# After iteration 109 : maximum power fraction remaining = 0.011378647078524063
# After iteration 110 : maximum power fraction remaining = 0.01120149904236482
# After iteration 111 : maximum power fraction remaining = 0.011027239275386949
# After iteration 112 : maximum power fraction remaining = 0.010855815891785678
# After iteration 113 : maximum power fraction remaining = 0.010687178178338953
# After iteration 114 : maximum power fraction remaining = 0.010521276552509782
# After iteration 115 : maximum power fraction remaining = 0.010358062523089089
# After iteration 116 : maximum power fraction remaining = 0.010197488653166466
# After iteration 117 : maximum power fraction remaining = 0.010039508525236664
# After iteration 118 : maximum power fraction remaining = 0.009884076708267964
# After iteration 1 : maximum power fraction remaining = 0.6686834055139865
# After iteration 2 : maximum power fraction remaining = 0.5421742653205024
# After iteration 3 : maximum power fraction remaining = 0.4911908803164058
# After iteration 4 : maximum power fraction remaining = 0.4321988008003771
# After iteration 5 : maximum power fraction remaining = 0.39480137710029994
# After iteration 6 : maximum power fraction remaining = 0.3532511730088841
# After iteration 7 : maximum power fraction remaining = 0.32254821302966474
# After iteration 8 : maximum power fraction remaining = 0.29037541538157086
# After iteration 9 : maximum power fraction remaining = 0.2647924274171611
# After iteration 10 : maximum power fraction remaining = 0.23921326453838263
# After iteration 11 : maximum power fraction remaining = 0.217922247000413
# After iteration 12 : maximum power fraction remaining = 0.19730492476356132
# After iteration 13 : maximum power fraction remaining = 0.17961750149035388
# After iteration 14 : maximum power fraction remaining = 0.16285293753467853
# After iteration 15 : maximum power fraction remaining = 0.1481824150522084
# After iteration 16 : maximum power fraction remaining = 0.13447327246397212
# After iteration 17 : maximum power fraction remaining = 0.12231968695289362
# After iteration 18 : maximum power fraction remaining = 0.11106809175790307
# After iteration 19 : maximum power fraction remaining = 0.1010080670750122
# After iteration 20 : maximum power fraction remaining = 0.09175168141174994
# After iteration 21 : maximum power fraction remaining = 0.08342930360236261
# After iteration 22 : maximum power fraction remaining = 0.07580269843726234
# After iteration 23 : maximum power fraction remaining = 0.068920433637817
# After iteration 24 : maximum power fraction remaining = 0.06263041540966613
# After iteration 25 : maximum power fraction remaining = 0.05694049487792699
# After iteration 26 : maximum power fraction remaining = 0.051749454696370996
# After iteration 27 : maximum power fraction remaining = 0.04704608791096081
# After iteration 28 : maximum power fraction remaining = 0.04276018380940418
# After iteration 29 : maximum power fraction remaining = 0.038872742497901513
# After iteration 30 : maximum power fraction remaining = 0.03533314845276821
# After iteration 31 : maximum power fraction remaining = 0.03212032097493719
# After iteration 32 : maximum power fraction remaining = 0.02919652957508735
# After iteration 33 : maximum power fraction remaining = 0.02654137248539378
# After iteration 34 : maximum power fraction remaining = 0.024125944059232622
# After iteration 35 : maximum power fraction remaining = 0.02193172824766645
# After iteration 36 : maximum power fraction remaining = 0.019936103605048387
# After iteration 37 : maximum power fraction remaining = 0.0181228463989337
# After iteration 38 : maximum power fraction remaining = 0.016473968682895048
# After iteration 39 : maximum power fraction remaining = 0.0149755488800691
# After iteration 40 : maximum power fraction remaining = 0.013613116669727037
# After iteration 41 : maximum power fraction remaining = 0.01237488005309268
# After iteration 42 : maximum power fraction remaining = 0.011249101932977644
# After iteration 43 : maximum power fraction remaining = 0.010225876872203629
# After iteration 44 : maximum power fraction remaining = 0.009295629413144855
# After iteration 1 : maximum power fraction remaining = 0.7684724326510826
# After iteration 2 : maximum power fraction remaining = 0.6498311402528363
# After iteration 3 : maximum power fraction remaining = 0.5556295516958326
# After iteration 4 : maximum power fraction remaining = 0.475973626994213
# After iteration 5 : maximum power fraction remaining = 0.4072446535625349
# After iteration 6 : maximum power fraction remaining = 0.34812714357062313
# After iteration 7 : maximum power fraction remaining = 0.29741499984944175
# After iteration 8 : maximum power fraction remaining = 0.2540106393446339
# After iteration 9 : maximum power fraction remaining = 0.21689946011769218
# After iteration 10 : maximum power fraction remaining = 0.18519244057776524
# After iteration 11 : maximum power fraction remaining = 0.1581115875950973
# After iteration 12 : maximum power fraction remaining = 0.13498690269749486
# After iteration 13 : maximum power fraction remaining = 0.11524244783383122
# After iteration 14 : maximum power fraction remaining = 0.09838515994671397
# After iteration 15 : maximum power fraction remaining = 0.08399330100084706
# After iteration 16 : maximum power fraction remaining = 0.07170651280730751
# After iteration 17 : maximum power fraction remaining = 0.061216987091023
# After iteration 18 : maximum power fraction remaining = 0.052261873603692076
# After iteration 19 : maximum power fraction remaining = 0.04461673874856148
# After iteration 20 : maximum power fraction remaining = 0.03808996505741144
# After iteration 21 : maximum power fraction remaining = 0.03251795863391486
# After iteration 22 : maximum power fraction remaining = 0.02776105370472796
# After iteration 23 : maximum power fraction remaining = 0.02370001403060036
# After iteration 24 : maximum power fraction remaining = 0.020233045201099434
# After iteration 25 : maximum power fraction remaining = 0.01727324352600968
# After iteration 26 : maximum power fraction remaining = 0.01474641791640587
# After iteration 27 : maximum power fraction remaining = 0.012589230296329025
# After iteration 28 : maximum power fraction remaining = 0.01074760800184742
# After iteration 29 : maximum power fraction remaining = 0.009175388402708666

# %% [markdown]
# Finally, we use TMM to calculate the absorption in a structure with a planar front and planar rear,
# as a reference.

# %%
struc = tmm_structure([Layer(si("200um"), Si)], incidence=Air, transmission=Air)
options.coherent = False
options.coherency_list = ["i"]
RAT = tmm_structure.calculate(struc, options)

# %% [markdown]
# ## Plotting
#
# Plot everything together, including data from the reference paper for comparison:

# %%
palhf = sns.color_palette("hls", 4)

fig = plt.figure()
plt.plot(sim_fig6[:, 0], sim_fig6[:, 1],
    "--", color=palhf[0], label="OPTOS - rear grating (1)")
plt.plot(wavelengths * 1e9, RAT_fig6["A_bulk"][0],
    "-o", color=palhf[0], label="RayFlare - rear grating (1)", fillstyle="none")
plt.plot(sim_fig7[:, 0], sim_fig7[:, 1],
    "--", color=palhf[1], label="OPTOS - front pyramids (2)",)
plt.plot(wavelengths * 1e9, RAT_fig7["A_bulk"][0],
    "-o", color=palhf[1], label="RayFlare - front pyramids (2)", fillstyle="none")
plt.plot(sim_fig8[:, 0], sim_fig8[:, 1],
    "--", color=palhf[2], label="OPTOS - grating + pyramids (3)")
plt.plot(wavelengths * 1e9, RAT_fig8["A_bulk"][0],
    "-o", color=palhf[2],label="RayFlare - grating + pyramids (3)", fillstyle="none",)
plt.plot(wavelengths * 1e9, RAT["A_per_layer"][:, 0], "-k", label="Planar")
plt.legend(loc="lower left")
plt.xlabel("Wavelength (nm)")
plt.ylabel("Absorption in Si")
plt.xlim([900, 1200])
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# We can see good agreement between the reference values and our calculated values. The structure
# with rear grating also behaves identically to the planar TMM reference case at the short wavelengths
# where front surface reflection dominates the result, as expected. Clearly, the pyramids perform
# much better overall, giving a large boost in the absorption at long wavelengths and also reducing the reflection
# significantly at shorter wavelengths. Plotting reflection and transmission emphasises this:

# %%
fig = plt.figure()
plt.plot(wavelengths * 1e9,RAT_fig6["R"][0],
    "-o", color=palhf[0], label="RayFlare - rear grating (1)", fillstyle="none")
plt.plot(wavelengths * 1e9, RAT_fig7["R"][0],
    "-o", color=palhf[1], label="RayFlare - front pyramids (2)", fillstyle="none")
plt.plot(wavelengths * 1e9, RAT_fig8["R"][0],
    "-o", color=palhf[2], label="RayFlare - grating + pyramids (3)", fillstyle="none")

plt.plot(wavelengths * 1e9, RAT_fig6["T"][0], "--o", color=palhf[0])
plt.plot(wavelengths * 1e9, RAT_fig7["T"][0], "--o", color=palhf[1])
plt.plot(wavelengths * 1e9, RAT_fig8["T"][0], "--o", color=palhf[2])

# these are just to create the legend:
plt.plot(-1, 0, "k-o", label="R", fillstyle="none")
plt.plot(-1, 0, "k--o", label="T")

plt.legend()
plt.xlabel("Wavelength (nm)")
plt.ylabel("Reflected/transmitted fraction")
plt.xlim([900, 1200])
plt.ylim([0, 0.6])
plt.show()

# %% [markdown]
# ## Redistribution matrices
#
# Plot the redistribution matrix for the rear grating (summed over azimuthal angles) at 1100 nm:

# %%
theta_intv, phi_intv, angle_vector = make_angle_vector(
    options["n_theta_bins"], options["phi_symmetry"], options["c_azimuth"])

path = get_savepath(save_location='current', project_name=options.project_name)
sprs = load_npz(os.path.join(path, SC_fig6[2].name + "frontRT.npz"))

wl_to_plot = 1100e-9
wl_index = np.argmin(np.abs(wavelengths - wl_to_plot))

full = sprs[wl_index].todense()

summat = theta_summary(full, angle_vector, options["n_theta_bins"], "front")
summat_r = summat[: options["n_theta_bins"], :]
summat_r = summat_r.rename({ r"$\theta_{in}$": r"$\sin(\theta_{in})$",
        r"$\theta_{out}$": r"$\sin(\theta_{out})$"})

summat_r = summat_r.assign_coords({r"$\sin(\theta_{in})$": np.sin(summat_r.coords[r"$\sin(\theta_{in})$"]).data,
    r"$\sin(\theta_{out})$": np.sin(summat_r.coords[r"$\sin(\theta_{out})$"]).data})

palhf = sns.cubehelix_palette(256, start=0.5, rot=-0.9)
palhf.reverse()
seamap = mpl.colors.ListedColormap(palhf)

fig = plt.figure()
ax = plt.subplot(111)
ax = summat_r.plot.imshow(ax=ax, cmap=seamap, vmax=0.3)
plt.show()

# %% [markdown]
# ## Questions
#
# - If you can add only one of the textures (pyramids or a grating), which one is
#   better? Why?
# - Why do the structures with a front-surface texture have high reflection at long
#   wavelengths? The anti-reflection properties of pyramids (treated with ray optics)
#   are mostly independent of the wavelength, so why does apparent reflection increase'
#   near the bandgap of Si?
# - Can you explain any of the features present in the angular redistribution matrix
#   of the rear grating surface?
