# %% [markdown]
# # Section 8: Textured Si
#
# This example is based on Figures 6, 7 and 8 from [this paper](https://doi.org/10.1364/OE.23.0A1720).
# This compares three different structures, all based on a 200 micron thick slab of silicon
# with different surface textures:
#
# 1. Planar front surface (TMM), crossed grating at rear (RCWA)
# 2. Inverted pyramids on the front surface (RT_Fresnel), planar rear surface (TMM)
# 3. Inverted pyramids on the front surface (RT_Fresnel), crossed grating at rear (RCWA)
#
# The methods which will be used to calculate the redistribution matrices in each case are given in
# brackets. If case 1 and 2 are calculated first, then case 3 does not require the calculations of
# any additional matrices, since it will use the rear matrix from (1) and the front matrix from (2).
#
# ## Setting up
#
# First, importing relevant packages:

# %%
import numpy as np
import os

# solcore imports
from solcore.structure import Layer
from solcore import material
from solcore import si

from rayflare.structure import Interface, BulkLayer, Structure
from rayflare.matrix_formalism import process_structure, calculate_RAT
from rayflare.utilities import get_savepath
from rayflare.transfer_matrix_method import tmm_structure
from rayflare.angles import theta_summary, make_angle_vector
from rayflare.textures import regular_pyramids
from rayflare.options import default_options

from solcore.material_system import create_new_material
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sparse import load_npz

# %% [markdown]
# To make sure we are using the same optical constants for Si, load the same Si n/k data used in the paper
# linked above:

# %%
create_new_material("Si_OPTOS", "data/Si_OPTOS_n.txt", "data/Si_OPTOS_k.txt",
                    overwrite=True)
# Out:
# Material created with optical constants n and k only.

# %% [markdown]
# You only need to do this one time, then the material will be stored in Solcore's material database.
#
# Setting options (taking the default options for everything not specified explicitly):

# %%
angle_degrees_in = 8 # same as in Fraunhofer paper

wavelengths = np.linspace(900, 1200, 20) * 1e-9

Si = material("Si_OPTOS")()
Air = material("Air")()

options = default_options()
options.wavelengths = wavelengths
options.theta_in = angle_degrees_in * np.pi / 180 # incidence angle (polar angle)
options.n_theta_bins = 100
options.c_azimuth = 0.25
options.n_rays = 25 * 25 * 1300 # number of rays per wavelength in ray-tracing
options.project_name = "OPTOS_comparison"
options.orders = 80 # number of RCWA orders to use (more = better convergence, but slower)
options.pol = "u" # unpolarized light

# %% [markdown]
# ## Defining the structures
#
# Now, set up the grating basis vectors for the RCWA calculations and define the grating structure.
# These are squares, rotated by 45 degrees. The halfwidth is calculated based on the area fill factor
# of the etched pillars given in the paper.

# %%
x = 1000

d_vectors = ((x, 0), (0, x))
area_fill_factor = 0.36
hw = np.sqrt(area_fill_factor) * 500

back_materials = [
    Layer(width=si("120nm"), material=Si,
        geometry=[{"type": "rectangle", "mat": Air, "center": (x / 2, x / 2),
                "halfwidths": (hw, hw), "angle": 45}],
    )]

# %% [markdown]
# Now we define the pyramid texture for the front surface in case (2) and (3) and make the four
# possible different surfaces: planar front and rear, front with pyramids, rear with grating.
# We specify the method to use to calculate the redistribution matrices in each case and create
# the bulk layer.

# %%
surf = regular_pyramids(elevation_angle=55, upright=False)

front_surf_pyramids = Interface(
    "RT_Fresnel",
    texture=surf,
    layers=[],
    name="inv_pyramids_front_" + str(options["n_rays"]),
)

front_surf_planar = Interface("TMM", layers=[], name="planar_front")

back_surf_grating = Interface(
    "RCWA",
    layers=back_materials,
    name="crossed_grating_back",
    d_vectors=d_vectors,
    rcwa_orders=20,
)

back_surf_planar = Interface("TMM", layers=[], name="planar_back")

bulk_Si = BulkLayer(201.8e-6, Si, name="Si_bulk")

# %% [markdown]
# Now we create the different structures and 'process' them (this will calculate the relevant
# matrices if necessary, or do nothing if it finds the matrices have previously been calculated and
# the files already exist). We don't need to process the final structure because it will use matrices
# calculated for `SC_fig6` and `SC_fig7`.

# %%
SC_fig6 = Structure(
    [front_surf_planar, bulk_Si, back_surf_grating], incidence=Air, transmission=Air
)
SC_fig7 = Structure(
    [front_surf_pyramids, bulk_Si, back_surf_planar], incidence=Air, transmission=Air
)
SC_fig8 = Structure(
    [front_surf_pyramids, bulk_Si, back_surf_grating], incidence=Air, transmission=Air
)

process_structure(SC_fig6, options, save_location='current')
process_structure(SC_fig7, options, save_location='current')
# Out:
# Making matrix for planar surface using TMM for element 0 in structure
# Existing angular redistribution matrices found
# Existing angular redistribution matrices found
# RCWA calculation for element 2 in structure
# Existing angular redistribution matrices found
# Ray tracing with Fresnel equations for element 0 in structure
# Existing angular redistribution matrices found
# Existing angular redistribution matrices found
# Making matrix for planar surface using TMM for element 2 in structure
# Existing angular redistribution matrices found

# %% [markdown]
# ## Calculating R/A/T
#
# Then we ask RayFlare to calculate the reflection, transmission and absorption through matrix
# multiplication, and get the required result out (absorption in the bulk) for each cell. We
# also load the results from the reference paper to compare them to the ones calculated with RayFlare.

# %%
#| output: false

results_fig6 = calculate_RAT(SC_fig6, options, save_location='current')
results_fig7 = calculate_RAT(SC_fig7, options, save_location='current')
results_fig8 = calculate_RAT(SC_fig8, options, save_location='current')

RAT_fig6 = results_fig6[0]
RAT_fig7 = results_fig7[0]
RAT_fig8 = results_fig8[0]

sim_fig6 = np.loadtxt("data/optos_fig6_sim.csv", delimiter=",")
sim_fig7 = np.loadtxt("data/optos_fig7_sim.csv", delimiter=",")
sim_fig8 = np.loadtxt("data/optos_fig8_sim.csv", delimiter=",")
# Out:
# After iteration 1 : maximum power fraction remaining = 0.30385597077212995
# After iteration 2 : maximum power fraction remaining = 0.2671653974599875
# After iteration 3 : maximum power fraction remaining = 0.2463560447364171
# After iteration 4 : maximum power fraction remaining = 0.22890222283014383
# After iteration 5 : maximum power fraction remaining = 0.21354637237665886
# After iteration 6 : maximum power fraction remaining = 0.19976181123138462
# After iteration 7 : maximum power fraction remaining = 0.18723743451871322
# After iteration 8 : maximum power fraction remaining = 0.17582765367195616
# After iteration 9 : maximum power fraction remaining = 0.16541767536839752
# After iteration 10 : maximum power fraction remaining = 0.15590858691015003
# After iteration 11 : maximum power fraction remaining = 0.14721237204715024
# After iteration 12 : maximum power fraction remaining = 0.13925001359444986
# After iteration 13 : maximum power fraction remaining = 0.13195046478914457
# After iteration 14 : maximum power fraction remaining = 0.12524984244645015
# After iteration 15 : maximum power fraction remaining = 0.11909069420403548
# After iteration 16 : maximum power fraction remaining = 0.11342132598386899
# After iteration 17 : maximum power fraction remaining = 0.10819519606074765
# After iteration 18 : maximum power fraction remaining = 0.10337037680918171
# After iteration 19 : maximum power fraction remaining = 0.09890907917308173
# After iteration 20 : maximum power fraction remaining = 0.09477723231123619
# After iteration 21 : maximum power fraction remaining = 0.09094411072024555
# After iteration 22 : maximum power fraction remaining = 0.08738200204758746
# After iteration 23 : maximum power fraction remaining = 0.08406590996125021
# After iteration 24 : maximum power fraction remaining = 0.08097328749084784
# After iteration 25 : maximum power fraction remaining = 0.07808379710267799
# After iteration 26 : maximum power fraction remaining = 0.0753790944260184
# After iteration 27 : maximum power fraction remaining = 0.07284263304832884
# After iteration 28 : maximum power fraction remaining = 0.07045948818185137
# After iteration 29 : maximum power fraction remaining = 0.06821619730446181
# After iteration 30 : maximum power fraction remaining = 0.06610061611627599
# After iteration 31 : maximum power fraction remaining = 0.06422571380644694
# After iteration 32 : maximum power fraction remaining = 0.06251273816231423
# After iteration 33 : maximum power fraction remaining = 0.06089725824730508
# After iteration 34 : maximum power fraction remaining = 0.05937064657293047
# After iteration 35 : maximum power fraction remaining = 0.05792512479453289
# After iteration 36 : maximum power fraction remaining = 0.05655367942747407
# After iteration 37 : maximum power fraction remaining = 0.05524998578700427
# After iteration 38 : maximum power fraction remaining = 0.05400833937142226
# After iteration 39 : maximum power fraction remaining = 0.0528235939801715
# After iteration 40 : maximum power fraction remaining = 0.05169110592383138
# After iteration 41 : maximum power fraction remaining = 0.0506066837422806
# After iteration 42 : maximum power fraction remaining = 0.04956654290125384
# After iteration 43 : maximum power fraction remaining = 0.04856726498661346
# After iteration 44 : maximum power fraction remaining = 0.04760576096037634
# After iteration 45 : maximum power fraction remaining = 0.046679238083272
# After iteration 46 : maximum power fraction remaining = 0.04578517014571342
# After iteration 47 : maximum power fraction remaining = 0.04492127068285292
# After iteration 48 : maximum power fraction remaining = 0.04408546888015508
# After iteration 49 : maximum power fraction remaining = 0.04327588790390124
# After iteration 50 : maximum power fraction remaining = 0.04249082541648437
# After iteration 51 : maximum power fraction remaining = 0.041728736059469695
# After iteration 52 : maximum power fraction remaining = 0.040988215708386996
# After iteration 53 : maximum power fraction remaining = 0.04026798732226439
# After iteration 54 : maximum power fraction remaining = 0.039566888228181246
# After iteration 55 : maximum power fraction remaining = 0.038883858696763085
# After iteration 56 : maximum power fraction remaining = 0.03821793167870765
# After iteration 57 : maximum power fraction remaining = 0.037568223585251234
# After iteration 58 : maximum power fraction remaining = 0.03693392600707633
# After iteration 59 : maximum power fraction remaining = 0.0363142982766418
# After iteration 60 : maximum power fraction remaining = 0.035708660788381044
# After iteration 61 : maximum power fraction remaining = 0.03511638899976145
# After iteration 62 : maximum power fraction remaining = 0.0345369080439117
# After iteration 63 : maximum power fraction remaining = 0.03396968789148116
# After iteration 64 : maximum power fraction remaining = 0.03341423900567047
# After iteration 65 : maximum power fraction remaining = 0.03287010844002723
# After iteration 66 : maximum power fraction remaining = 0.03233687633369684
# After iteration 67 : maximum power fraction remaining = 0.03181415276340789
# After iteration 68 : maximum power fraction remaining = 0.03130157491560476
# After iteration 69 : maximum power fraction remaining = 0.030798804545859846
# After iteration 70 : maximum power fraction remaining = 0.03030552569604594
# After iteration 71 : maximum power fraction remaining = 0.02982144264276101
# After iteration 72 : maximum power fraction remaining = 0.02934627805320663
# After iteration 73 : maximum power fraction remaining = 0.028879771327157033
# After iteration 74 : maximum power fraction remaining = 0.02842167710584603
# After iteration 75 : maximum power fraction remaining = 0.02797176393056648
# After iteration 76 : maximum power fraction remaining = 0.027529813035546448
# After iteration 77 : maximum power fraction remaining = 0.02709561726125428
# After iteration 78 : maximum power fraction remaining = 0.026668980075712646
# After iteration 79 : maximum power fraction remaining = 0.026249714692682877
# After iteration 80 : maximum power fraction remaining = 0.0258376432767317
# After iteration 81 : maximum power fraction remaining = 0.025432596226225797
# After iteration 82 : maximum power fraction remaining = 0.025034411526226437
# After iteration 83 : maximum power fraction remaining = 0.024642934164088654
# After iteration 84 : maximum power fraction remaining = 0.024258015601316
# After iteration 85 : maximum power fraction remaining = 0.023879513295891382
# After iteration 86 : maximum power fraction remaining = 0.02350729026990526
# After iteration 87 : maximum power fraction remaining = 0.023141214717841106
# After iteration 88 : maximum power fraction remaining = 0.022781159651360818
# After iteration 89 : maximum power fraction remaining = 0.022427002576865827
# After iteration 90 : maximum power fraction remaining = 0.02207862520249774
# After iteration 91 : maximum power fraction remaining = 0.021735913171589818
# After iteration 92 : maximum power fraction remaining = 0.021398755819892572
# After iteration 93 : maximum power fraction remaining = 0.02106704595417568
# After iteration 94 : maximum power fraction remaining = 0.0207406796500585
# After iteration 95 : maximum power fraction remaining = 0.020419556067145593
# After iteration 96 : maximum power fraction remaining = 0.020103577279743972
# After iteration 97 : maximum power fraction remaining = 0.019792648121618704
# After iteration 98 : maximum power fraction remaining = 0.019486676043403945
# After iteration 99 : maximum power fraction remaining = 0.019185570981430623
# After iteration 100 : maximum power fraction remaining = 0.01888924523686074
# After iteration 101 : maximum power fraction remaining = 0.01859761336413347
# After iteration 102 : maximum power fraction remaining = 0.01831059206783157
# After iteration 103 : maximum power fraction remaining = 0.01802810010716864
# After iteration 104 : maximum power fraction remaining = 0.017750058207380685
# After iteration 105 : maximum power fraction remaining = 0.01747638897737896
# After iteration 106 : maximum power fraction remaining = 0.017207016833087504
# After iteration 107 : maximum power fraction remaining = 0.01694186792594752
# After iteration 108 : maximum power fraction remaining = 0.016680870076123993
# After iteration 109 : maximum power fraction remaining = 0.01642395270999689
# After iteration 110 : maximum power fraction remaining = 0.01617104680156185
# After iteration 111 : maximum power fraction remaining = 0.01592208481740292
# After iteration 112 : maximum power fraction remaining = 0.0156770006649338
# After iteration 113 : maximum power fraction remaining = 0.015435729643634339
# After iteration 114 : maximum power fraction remaining = 0.015198208399036059
# After iteration 115 : maximum power fraction remaining = 0.014964374879234707
# After iteration 116 : maximum power fraction remaining = 0.014734168293729553
# After iteration 117 : maximum power fraction remaining = 0.014507529074408491
# After iteration 118 : maximum power fraction remaining = 0.014284398838515388
# After iteration 119 : maximum power fraction remaining = 0.01406472035345162
# After iteration 120 : maximum power fraction remaining = 0.013848437503277805
# After iteration 121 : maximum power fraction remaining = 0.013635495256793981
# After iteration 122 : maximum power fraction remaining = 0.013425839637087818
# After iteration 123 : maximum power fraction remaining = 0.013219417692450455
# After iteration 124 : maximum power fraction remaining = 0.013016177468568455
# After iteration 125 : maximum power fraction remaining = 0.012816067981908564
# After iteration 126 : maximum power fraction remaining = 0.012619039194219004
# After iteration 127 : maximum power fraction remaining = 0.012425041988077831
# After iteration 128 : maximum power fraction remaining = 0.012234028143424402
# After iteration 129 : maximum power fraction remaining = 0.01204595031501558
# After iteration 130 : maximum power fraction remaining = 0.011860762010752743
# After iteration 131 : maximum power fraction remaining = 0.01167841757083027
# After iteration 132 : maximum power fraction remaining = 0.011498872147659702
# After iteration 133 : maximum power fraction remaining = 0.011322081686527527
# After iteration 134 : maximum power fraction remaining = 0.011148002906947521
# After iteration 135 : maximum power fraction remaining = 0.010976593284671559
# After iteration 136 : maximum power fraction remaining = 0.010807811034325253
# After iteration 137 : maximum power fraction remaining = 0.01064161509263728
# After iteration 138 : maximum power fraction remaining = 0.010477965102233307
# After iteration 139 : maximum power fraction remaining = 0.010316821395967343
# After iteration 140 : maximum power fraction remaining = 0.01015814498176526
# After iteration 141 : maximum power fraction remaining = 0.01000189752795665
# After iteration 142 : maximum power fraction remaining = 0.00984804134907286
# After iteration 1 : maximum power fraction remaining = 0.6641759331974262
# After iteration 2 : maximum power fraction remaining = 0.5378254387801145
# After iteration 3 : maximum power fraction remaining = 0.48800711629289484
# After iteration 4 : maximum power fraction remaining = 0.4239382685779792
# After iteration 5 : maximum power fraction remaining = 0.3884658524821204
# After iteration 6 : maximum power fraction remaining = 0.34261394937922657
# After iteration 7 : maximum power fraction remaining = 0.31303325707054425
# After iteration 8 : maximum power fraction remaining = 0.27861803533284
# After iteration 9 : maximum power fraction remaining = 0.25373492184784846
# After iteration 10 : maximum power fraction remaining = 0.22713104000410148
# After iteration 11 : maximum power fraction remaining = 0.20635757874709448
# After iteration 12 : maximum power fraction remaining = 0.18541161901774927
# After iteration 13 : maximum power fraction remaining = 0.16819369605501627
# After iteration 14 : maximum power fraction remaining = 0.15148827978715573
# After iteration 15 : maximum power fraction remaining = 0.13728485350842207
# After iteration 16 : maximum power fraction remaining = 0.12384426328049762
# After iteration 17 : maximum power fraction remaining = 0.11216251701808372
# After iteration 18 : maximum power fraction remaining = 0.10128500896228171
# After iteration 19 : maximum power fraction remaining = 0.09169508579301365
# After iteration 20 : maximum power fraction remaining = 0.08285753822775711
# After iteration 21 : maximum power fraction remaining = 0.07499389240945997
# After iteration 22 : maximum power fraction remaining = 0.06779526381582776
# After iteration 23 : maximum power fraction remaining = 0.061351691521929715
# After iteration 24 : maximum power fraction remaining = 0.055478133945665094
# After iteration 25 : maximum power fraction remaining = 0.05020045800659059
# After iteration 26 : maximum power fraction remaining = 0.04540274935445329
# After iteration 27 : maximum power fraction remaining = 0.041081138798660995
# After iteration 28 : maximum power fraction remaining = 0.03715937252264126
# After iteration 29 : maximum power fraction remaining = 0.033621186652450646
# After iteration 30 : maximum power fraction remaining = 0.03041391479251114
# After iteration 31 : maximum power fraction remaining = 0.027517402675694042
# After iteration 32 : maximum power fraction remaining = 0.024893639432780737
# After iteration 33 : maximum power fraction remaining = 0.02252255820281119
# After iteration 34 : maximum power fraction remaining = 0.02037570893554479
# After iteration 35 : maximum power fraction remaining = 0.01843480566781109
# After iteration 36 : maximum power fraction remaining = 0.01667795067712921
# After iteration 37 : maximum power fraction remaining = 0.01508920768709752
# After iteration 38 : maximum power fraction remaining = 0.013651377004527577
# After iteration 39 : maximum power fraction remaining = 0.012350910532099513
# After iteration 40 : maximum power fraction remaining = 0.011174106917680397
# After iteration 41 : maximum power fraction remaining = 0.010109614882747392
# After iteration 42 : maximum power fraction remaining = 0.00914641562033823
# After iteration 1 : maximum power fraction remaining = 0.7669365225940882
# After iteration 2 : maximum power fraction remaining = 0.6554424943151556
# After iteration 3 : maximum power fraction remaining = 0.5612348278217695
# After iteration 4 : maximum power fraction remaining = 0.47994350256790913
# After iteration 5 : maximum power fraction remaining = 0.4089633078935878
# After iteration 6 : maximum power fraction remaining = 0.3480369858452092
# After iteration 7 : maximum power fraction remaining = 0.2958828150440518
# After iteration 8 : maximum power fraction remaining = 0.25141431350077664
# After iteration 9 : maximum power fraction remaining = 0.21355965190798396
# After iteration 10 : maximum power fraction remaining = 0.1813720469331235
# After iteration 11 : maximum power fraction remaining = 0.15401942072087266
# After iteration 12 : maximum power fraction remaining = 0.13078391872278283
# After iteration 13 : maximum power fraction remaining = 0.11104986584594453
# After iteration 14 : maximum power fraction remaining = 0.09429159620563327
# After iteration 15 : maximum power fraction remaining = 0.08006135166892403
# After iteration 16 : maximum power fraction remaining = 0.06797824508136699
# After iteration 17 : maximum power fraction remaining = 0.057718537141252635
# After iteration 18 : maximum power fraction remaining = 0.049007180925907286
# After iteration 19 : maximum power fraction remaining = 0.04161056130612999
# After iteration 20 : maximum power fraction remaining = 0.0353302823773529
# After iteration 21 : maximum power fraction remaining = 0.02999787280663326
# After iteration 22 : maximum power fraction remaining = 0.025470279115767346
# After iteration 23 : maximum power fraction remaining = 0.02162603432746957
# After iteration 24 : maximum power fraction remaining = 0.018362002263729083
# After iteration 25 : maximum power fraction remaining = 0.01559061204888777
# After iteration 26 : maximum power fraction remaining = 0.013237509395657595
# After iteration 27 : maximum power fraction remaining = 0.011239562097805304
# After iteration 28 : maximum power fraction remaining = 0.009543166409611321

# %% [markdown]
# Finally, we use TMM to calculate the absorption in a structure with a planar front and planar rear,
# as a reference.

# %%
struc = tmm_structure([Layer(si("200um"), Si)], incidence=Air, transmission=Air)
options.coherent = False
options.coherency_list = ["i"]
RAT = tmm_structure.calculate(struc, options)

# %% [markdown]
# ## Plotting
#
# Plot everything together, including data from the reference paper for comparison:

# %%
palhf = sns.color_palette("hls", 4)

fig = plt.figure()
plt.plot(sim_fig6[:, 0], sim_fig6[:, 1],
    "--", color=palhf[0], label="OPTOS - rear grating (1)")
plt.plot(wavelengths * 1e9, RAT_fig6["A_bulk"][0],
    "-o", color=palhf[0], label="RayFlare - rear grating (1)", fillstyle="none")
plt.plot(sim_fig7[:, 0], sim_fig7[:, 1],
    "--", color=palhf[1], label="OPTOS - front pyramids (2)",)
plt.plot(wavelengths * 1e9, RAT_fig7["A_bulk"][0],
    "-o", color=palhf[1], label="RayFlare - front pyramids (2)", fillstyle="none")
plt.plot(sim_fig8[:, 0], sim_fig8[:, 1],
    "--", color=palhf[2], label="OPTOS - grating + pyramids (3)")
plt.plot(wavelengths * 1e9, RAT_fig8["A_bulk"][0],
    "-o", color=palhf[2],label="RayFlare - grating + pyramids (3)", fillstyle="none",)
plt.plot(wavelengths * 1e9, RAT["A_per_layer"][:, 0], "-k", label="Planar")
plt.legend(loc="lower left")
plt.xlabel("Wavelength (nm)")
plt.ylabel("Absorption in Si")
plt.xlim([900, 1200])
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# We can see good agreement between the reference values and our calculated values. The structure
# with rear grating also behaves identically to the planar TMM reference case at the short wavelengths
# where front surface reflection dominates the result, as expected. Clearly, the pyramids perform
# much better overall, giving a large boost in the absorption at long wavelengths and also reducing the reflection
# significantly at shorter wavelengths. Plotting reflection and transmission emphasises this:

# %%
fig = plt.figure()
plt.plot(wavelengths * 1e9,RAT_fig6["R"][0],
    "-o", color=palhf[0], label="RayFlare - rear grating (1)", fillstyle="none")
plt.plot(wavelengths * 1e9, RAT_fig7["R"][0],
    "-o", color=palhf[1], label="RayFlare - front pyramids (2)", fillstyle="none")
plt.plot(wavelengths * 1e9, RAT_fig8["R"][0],
    "-o", color=palhf[2], label="RayFlare - grating + pyramids (3)", fillstyle="none")

plt.plot(wavelengths * 1e9, RAT_fig6["T"][0], "--o", color=palhf[0])
plt.plot(wavelengths * 1e9, RAT_fig7["T"][0], "--o", color=palhf[1])
plt.plot(wavelengths * 1e9, RAT_fig8["T"][0], "--o", color=palhf[2])

# these are just to create the legend:
plt.plot(-1, 0, "k-o", label="R", fillstyle="none")
plt.plot(-1, 0, "k--o", label="T")

plt.legend()
plt.xlabel("Wavelength (nm)")
plt.ylabel("Reflected/transmitted fraction")
plt.xlim([900, 1200])
plt.ylim([0, 0.6])
plt.show()

# %% [markdown]
# ## Redistribution matrices
#
# Plot the redistribution matrix for the rear grating (summed over azimuthal angles) at 1100 nm:

# %%
theta_intv, phi_intv, angle_vector = make_angle_vector(
    options["n_theta_bins"], options["phi_symmetry"], options["c_azimuth"])

path = get_savepath("default", options.project_name)
sprs = load_npz(os.path.join(path, SC_fig6[2].name + "frontRT.npz"))

wl_to_plot = 1100e-9
wl_index = np.argmin(np.abs(wavelengths - wl_to_plot))

full = sprs[wl_index].todense()

summat = theta_summary(full, angle_vector, options["n_theta_bins"], "front")
summat_r = summat[: options["n_theta_bins"], :]
summat_r = summat_r.rename({ r"$\theta_{in}$": r"$\sin(\theta_{in})$",
        r"$\theta_{out}$": r"$\sin(\theta_{out})$"})

summat_r = summat_r.assign_coords({r"$\sin(\theta_{in})$": np.sin(summat_r.coords[r"$\sin(\theta_{in})$"]).data,
    r"$\sin(\theta_{out})$": np.sin(summat_r.coords[r"$\sin(\theta_{out})$"]).data})

palhf = sns.cubehelix_palette(256, start=0.5, rot=-0.9)
palhf.reverse()
seamap = mpl.colors.ListedColormap(palhf)

fig = plt.figure()
ax = plt.subplot(111)
ax = summat_r.plot.imshow(ax=ax, cmap=seamap, vmax=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 12
#       8 wl_index = np.argmin(np.abs(wavelengths - wl_to_plot))
#      10 full = sprs[wl_index].todense()
# ---> 12 summat = theta_summary(full, angle_vector, options["n_theta_bins"], "front")
#      13 summat_r = summat[: options["n_theta_bins"], :]
#      14 summat_r = summat_r.rename({ r"$\theta_{in}$": r"$\sin(\theta_{in})$",
#      15         r"$\theta_{out}$": r"$\sin(\theta_{out})$"})
#
# File ~/Documents/develop/solcore-education/venv/lib/python3.11/site-packages/rayflare/angles.py:120, in theta_summary(out_mat, angle_vector, n_theta_bins, front_or_rear)
#     115 sum_mat = sum_mat.groupby("theta_out").map(
#     116     weighted_mean, args=("theta_out", 0, None)
#     117 )
#     119 if front_or_rear == "front":
# --> 120     sum_mat = xr.DataArray(
#     121         sum_mat.data,
#     122         dims=[r"$\theta_{out}$", r"$\theta_{in}$"],
#     123         coords={
#     124             r"$\theta_{out}$": theta_all,
#     125             r"$\theta_{in}$": theta_all[: sum_mat.shape[1]],
#     126         },
#     127     )
#     129 else:
#     130     sum_mat = xr.DataArray(
#     131         sum_mat.data,
#     132         dims=[r"$\theta_{out}$", r"$\theta_{in}$"],
#     133         coords={r"$\theta_{out}$": theta_all, r"$\theta_{in}$": theta_t},
#     134     )
#
# File ~/Documents/develop/solcore-education/venv/lib/python3.11/site-packages/xarray/core/dataarray.py:423, in DataArray.__init__(self, data, coords, dims, name, attrs, indexes, fastpath)
#     421 data = _check_data_shape(data, coords, dims)
#     422 data = as_compatible_data(data)
# --> 423 coords, dims = _infer_coords_and_dims(data.shape, coords, dims)
#     424 variable = Variable(dims, data, attrs, fastpath=True)
#     425 indexes, coords = _create_indexes_from_coords(coords)
#
# File ~/Documents/develop/solcore-education/venv/lib/python3.11/site-packages/xarray/core/dataarray.py:169, in _infer_coords_and_dims(shape, coords, dims)
#     167 for d, s in zip(v.dims, v.shape):
#     168     if s != sizes[d]:
# --> 169         raise ValueError(
#     170             f"conflicting sizes for dimension {d!r}: "
#     171             f"length {sizes[d]} on the data but length {s} on "
#     172             f"coordinate {k!r}"
#     173         )
#     175 if k in sizes and v.shape != (sizes[k],):
#     176     raise ValueError(
#     177         f"coordinate {k!r} is a DataArray dimension, but "
#     178         f"it has shape {v.shape!r} rather than expected shape {sizes[k]!r} "
#     179         "matching the dimension size"
#     180     )
#
# ValueError: conflicting sizes for dimension '$\\theta_{out}$': length 72 on the data but length 200 on coordinate '$\\theta_{out}$'

# %% [markdown]
# ## Questions
#
# - If you can add only one of the textures (pyramids or a grating), which one is
#   better? Why?
# - Why do the structures with a front-surface texture have high reflection at long
#   wavelengths? The anti-reflection properties of pyramids (treated with ray optics)
#   are mostly independent of the wavelength, so why does apparent reflection increase'
#   near the bandgap of Si?
# - Can you explain any of the features present in the angular redistribution matrix
#   of the rear grating surface?
