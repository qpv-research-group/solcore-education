# %% [markdown]
# # Section 8: Textured Si
#
# This example is based on Figures 6, 7 and 8 from [this paper](https://doi.org/10.1364/OE.23.0A1720).
# This compares three different structures, all based on a 200 micron thick slab of silicon
# with different surface textures:
#
# 1. Planar front surface (TMM), crossed grating at rear (RCWA)
# 2. Inverted pyramids on the front surface (RT_Fresnel), planar rear surface (TMM)
# 3. Inverted pyramids on the front surface (RT_Fresnel), crossed grating at rear (RCWA)
#
# The methods which will be used to calculate the redistribution matrices in each case are given in
# brackets. If case 1 and 2 are calculated first, then case 3 does not require the calculations of
# any additional matrices, since it will use the rear matrix from (1) and the front matrix from (2).
#
# ## Setting up
#
# First, importing relevant packages:

# %%
import numpy as np
import os

# solcore imports
from solcore.structure import Layer
from solcore import material
from solcore import si

from rayflare.structure import Interface, BulkLayer, Structure
from rayflare.matrix_formalism import process_structure, calculate_RAT
from rayflare.utilities import get_savepath
from rayflare.transfer_matrix_method import tmm_structure
from rayflare.angles import theta_summary, make_angle_vector
from rayflare.textures import regular_pyramids
from rayflare.options import default_options

from solcore.material_system import create_new_material
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sparse import load_npz

# %% [markdown]
# To make sure we are using the same optical constants for Si, load the same Si n/k data used in the paper
# linked above:

# %%
create_new_material("Si_OPTOS", "data/Si_OPTOS_n.txt", "data/Si_OPTOS_k.txt",
                    overwrite=True)
# Out:
# Material created with optical constants n and k only.

# %% [markdown]
# You only need to do this one time, then the material will be stored in Solcore's material database.
#
# Setting options (taking the default options for everything not specified explicitly):

# %%
angle_degrees_in = 8 # same as in Fraunhofer paper

wavelengths = np.linspace(900, 1200, 20) * 1e-9

Si = material("Si_OPTOS")()
Air = material("Air")()

options = default_options()
options.wavelengths = wavelengths
options.theta_in = angle_degrees_in * np.pi / 180 # incidence angle (polar angle)
options.n_theta_bins = 50
options.c_azimuth = 0.25
options.n_rays = 5e5 # number of rays per wavelength in ray-tracing
options.project_name = "OPTOS_comparison"
options.orders = 60 # number of RCWA orders to use (more = better convergence, but slower)
options.pol = "u" # unpolarized light
options.only_incidence_angle = False

# %% [markdown]
# ## Defining the structures
#
# Now, set up the grating basis vectors for the RCWA calculations and define the grating structure.
# These are squares, rotated by 45 degrees. The halfwidth is calculated based on the area fill factor
# of the etched pillars given in the paper.

# %%
x = 1000

d_vectors = ((x, 0), (0, x))
area_fill_factor = 0.36
hw = np.sqrt(area_fill_factor) * 500

back_materials = [
    Layer(width=si("120nm"), material=Si,
        geometry=[{"type": "rectangle", "mat": Air, "center": (x / 2, x / 2),
                "halfwidths": (hw, hw), "angle": 45}],
    )]

# %% [markdown]
# Now we define the pyramid texture for the front surface in case (2) and (3) and make the four
# possible different surfaces: planar front and rear, front with pyramids, rear with grating.
# We specify the method to use to calculate the redistribution matrices in each case and create
# the bulk layer.

# %%
surf = regular_pyramids(elevation_angle=55, upright=False)

front_surf_pyramids = Interface(
    "RT_Fresnel",
    texture=surf,
    layers=[],
    name="inv_pyramids_front_" + str(options["n_rays"]),
)

front_surf_planar = Interface("TMM", layers=[], name="planar_front")

back_surf_grating = Interface(
    "RCWA",
    layers=back_materials,
    name="crossed_grating_back",
    d_vectors=d_vectors,
    rcwa_orders=20,
)

back_surf_planar = Interface("TMM", layers=[], name="planar_back")

bulk_Si = BulkLayer(201.8e-6, Si, name="Si_bulk")
# Out:
# fixed h 0.7140740033710572

# %% [markdown]
# Now we create the different structures and 'process' them (this will calculate the relevant
# matrices if necessary, or do nothing if it finds the matrices have previously been calculated and
# the files already exist). We don't need to process the final structure because it will use matrices
# calculated for `SC_fig6` and `SC_fig7`.

# %%
SC_fig6 = Structure(
    [front_surf_planar, bulk_Si, back_surf_grating], incidence=Air, transmission=Air
)
SC_fig7 = Structure(
    [front_surf_pyramids, bulk_Si, back_surf_planar], incidence=Air, transmission=Air
)
SC_fig8 = Structure(
    [front_surf_pyramids, bulk_Si, back_surf_grating], incidence=Air, transmission=Air
)

process_structure(SC_fig6, options, save_location='current')
process_structure(SC_fig7, options, save_location='current')
# Out:
# Making matrix for planar surface using TMM for element 0 in structure
# Existing angular redistribution matrices found
# Existing angular redistribution matrices found
# RCWA calculation for element 2 in structure
# Existing angular redistribution matrices found
# Ray tracing with Fresnel equations for element 0 in structure
# Existing angular redistribution matrices found
# Existing angular redistribution matrices found
# Making matrix for planar surface using TMM for element 2 in structure
# Existing angular redistribution matrices found

# %% [markdown]
# ## Calculating R/A/T
#
# Then we ask RayFlare to calculate the reflection, transmission and absorption through matrix
# multiplication, and get the required result out (absorption in the bulk) for each cell. We
# also load the results from the reference paper to compare them to the ones calculated with RayFlare.

# %%
#| output: false

results_fig6 = calculate_RAT(SC_fig6, options, save_location='current')
results_fig7 = calculate_RAT(SC_fig7, options, save_location='current')
results_fig8 = calculate_RAT(SC_fig8, options, save_location='current')

RAT_fig6 = results_fig6[0]
RAT_fig7 = results_fig7[0]
RAT_fig8 = results_fig8[0]

sim_fig6 = np.loadtxt("data/optos_fig6_sim.csv", delimiter=",")
sim_fig7 = np.loadtxt("data/optos_fig7_sim.csv", delimiter=",")
sim_fig8 = np.loadtxt("data/optos_fig8_sim.csv", delimiter=",")
# Out:
# After iteration 1 : maximum power fraction remaining = 0.30465002433410837
# After iteration 2 : maximum power fraction remaining = 0.2652106769651226
# After iteration 3 : maximum power fraction remaining = 0.24103700590713126
# After iteration 4 : maximum power fraction remaining = 0.22161642857589176
# After iteration 5 : maximum power fraction remaining = 0.20443557859600767
# After iteration 6 : maximum power fraction remaining = 0.18894462575398507
# After iteration 7 : maximum power fraction remaining = 0.17489612559811535
# After iteration 8 : maximum power fraction remaining = 0.1621463100610234
# After iteration 9 : maximum power fraction remaining = 0.15058141555744542
# After iteration 10 : maximum power fraction remaining = 0.14009718022302928
# After iteration 11 : maximum power fraction remaining = 0.13059498662884955
# After iteration 12 : maximum power fraction remaining = 0.12198218584836196
# After iteration 13 : maximum power fraction remaining = 0.11417285327268858
# After iteration 14 : maximum power fraction remaining = 0.10708814424538776
# After iteration 15 : maximum power fraction remaining = 0.10065624158949266
# After iteration 16 : maximum power fraction remaining = 0.0948120434479826
# After iteration 17 : maximum power fraction remaining = 0.08949671947877563
# After iteration 18 : maximum power fraction remaining = 0.08465721679468552
# After iteration 19 : maximum power fraction remaining = 0.08024576092426364
# After iteration 20 : maximum power fraction remaining = 0.07621937486344181
# After iteration 21 : maximum power fraction remaining = 0.07253942697270063
# After iteration 22 : maximum power fraction remaining = 0.06917121199946927
# After iteration 23 : maximum power fraction remaining = 0.06608356618570495
# After iteration 24 : maximum power fraction remaining = 0.06324851573452964
# After iteration 25 : maximum power fraction remaining = 0.060640957061909265
# After iteration 26 : maximum power fraction remaining = 0.05823836684967172
# After iteration 27 : maximum power fraction remaining = 0.05602053974460331
# After iteration 28 : maximum power fraction remaining = 0.05396935151208375
# After iteration 29 : maximum power fraction remaining = 0.0520685454958787
# After iteration 30 : maximum power fraction remaining = 0.05030354032583835
# After iteration 31 : maximum power fraction remaining = 0.04866125693226023
# After iteration 32 : maximum power fraction remaining = 0.04712996305655717
# After iteration 33 : maximum power fraction remaining = 0.04569913358404002
# After iteration 34 : maximum power fraction remaining = 0.04435932516040642
# After iteration 35 : maximum power fraction remaining = 0.04310206368524812
# After iteration 36 : maximum power fraction remaining = 0.04191974340127357
# After iteration 37 : maximum power fraction remaining = 0.04080553641568109
# After iteration 38 : maximum power fraction remaining = 0.0397533115995768
# After iteration 39 : maximum power fraction remaining = 0.03875756191233035
# After iteration 40 : maximum power fraction remaining = 0.03781333929042185
# After iteration 41 : maximum power fraction remaining = 0.036916196324971076
# After iteration 42 : maximum power fraction remaining = 0.036062134029182936
# After iteration 43 : maximum power fraction remaining = 0.03524755506688543
# After iteration 44 : maximum power fraction remaining = 0.034469221876694364
# After iteration 45 : maximum power fraction remaining = 0.03372421918363513
# After iteration 46 : maximum power fraction remaining = 0.03300992044179206
# After iteration 47 : maximum power fraction remaining = 0.032323957798224896
# After iteration 48 : maximum power fraction remaining = 0.03166419521044561
# After iteration 49 : maximum power fraction remaining = 0.031028704387613106
# After iteration 50 : maximum power fraction remaining = 0.030415743259669354
# After iteration 51 : maximum power fraction remaining = 0.02982373670927263
# After iteration 52 : maximum power fraction remaining = 0.02925125932890987
# After iteration 53 : maximum power fraction remaining = 0.02869701999029609
# After iteration 54 : maximum power fraction remaining = 0.02815984803536686
# After iteration 55 : maximum power fraction remaining = 0.027638680918092018
# After iteration 56 : maximum power fraction remaining = 0.027132553144210945
# After iteration 57 : maximum power fraction remaining = 0.026640586372017192
# After iteration 58 : maximum power fraction remaining = 0.02616198055168929
# After iteration 59 : maximum power fraction remaining = 0.02569600599354254
# After iteration 60 : maximum power fraction remaining = 0.02524199626711515
# After iteration 61 : maximum power fraction remaining = 0.024799341843338006
# After iteration 62 : maximum power fraction remaining = 0.02436748440129351
# After iteration 63 : maximum power fraction remaining = 0.02394591172935668
# After iteration 64 : maximum power fraction remaining = 0.023534153157930116
# After iteration 65 : maximum power fraction remaining = 0.023131775467624422
# After iteration 66 : maximum power fraction remaining = 0.022738379222676817
# After iteration 67 : maximum power fraction remaining = 0.022353595484716392
# After iteration 68 : maximum power fraction remaining = 0.021977082866739647
# After iteration 69 : maximum power fraction remaining = 0.021608524891412812
# After iteration 70 : maximum power fraction remaining = 0.021247627621621107
# After iteration 71 : maximum power fraction remaining = 0.02089411753458621
# After iteration 72 : maximum power fraction remaining = 0.020547739613914116
# After iteration 73 : maximum power fraction remaining = 0.02020825563665437
# After iteration 74 : maximum power fraction remaining = 0.019875442634881876
# After iteration 75 : maximum power fraction remaining = 0.01954909151348516
# After iteration 76 : maximum power fraction remaining = 0.019229005807786435
# After iteration 77 : maximum power fraction remaining = 0.018915000566354822
# After iteration 78 : maximum power fraction remaining = 0.018606901345924572
# After iteration 79 : maximum power fraction remaining = 0.01830454330671686
# After iteration 80 : maximum power fraction remaining = 0.018007770397702193
# After iteration 81 : maximum power fraction remaining = 0.017716434622447652
# After iteration 82 : maximum power fraction remaining = 0.017430395377182495
# After iteration 83 : maximum power fraction remaining = 0.017149518853599676
# After iteration 84 : maximum power fraction remaining = 0.016873677499700944
# After iteration 85 : maximum power fraction remaining = 0.0166027495326991
# After iteration 86 : maximum power fraction remaining = 0.0163366184986221
# After iteration 87 : maximum power fraction remaining = 0.01607517287382733
# After iteration 88 : maximum power fraction remaining = 0.01581830570413854
# After iteration 89 : maximum power fraction remaining = 0.015565914277768121
# After iteration 90 : maximum power fraction remaining = 0.015317899828590121
# After iteration 91 : maximum power fraction remaining = 0.01507416726668914
# After iteration 92 : maximum power fraction remaining = 0.014834624933431852
# After iteration 93 : maximum power fraction remaining = 0.014599184378595578
# After iteration 94 : maximum power fraction remaining = 0.014367760157345264
# After iteration 95 : maximum power fraction remaining = 0.014140269645080207
# After iteration 96 : maximum power fraction remaining = 0.013916632868377243
# After iteration 97 : maximum power fraction remaining = 0.013696772350441137
# After iteration 98 : maximum power fraction remaining = 0.01348061296963708
# After iteration 99 : maximum power fraction remaining = 0.013268081829827468
# After iteration 100 : maximum power fraction remaining = 0.013059108141366509
# After iteration 101 : maximum power fraction remaining = 0.012853623111724055
# After iteration 102 : maximum power fraction remaining = 0.012651559844815327
# After iteration 103 : maximum power fraction remaining = 0.012452853248207442
# After iteration 104 : maximum power fraction remaining = 0.012257439947458142
# After iteration 105 : maximum power fraction remaining = 0.01206525820691759
# After iteration 106 : maximum power fraction remaining = 0.01187624785639177
# After iteration 107 : maximum power fraction remaining = 0.011690350223126696
# After iteration 108 : maximum power fraction remaining = 0.011507508068626826
# After iteration 109 : maximum power fraction remaining = 0.01132766552986979
# After iteration 110 : maximum power fraction remaining = 0.011150768064523092
# After iteration 111 : maximum power fraction remaining = 0.010976762399807553
# After iteration 112 : maximum power fraction remaining = 0.010805596484687336
# After iteration 113 : maximum power fraction remaining = 0.010637219445097669
# After iteration 114 : maximum power fraction remaining = 0.010471581541949868
# After iteration 115 : maximum power fraction remaining = 0.010308634131678228
# After iteration 116 : maximum power fraction remaining = 0.010148329629116363
# After iteration 117 : maximum power fraction remaining = 0.009990621472510793
# After iteration 1 : maximum power fraction remaining = 0.6686658895180349
# After iteration 2 : maximum power fraction remaining = 0.5421593545283252
# After iteration 3 : maximum power fraction remaining = 0.4911675614790785
# After iteration 4 : maximum power fraction remaining = 0.43217077364774925
# After iteration 5 : maximum power fraction remaining = 0.3947681838889838
# After iteration 6 : maximum power fraction remaining = 0.3532151851781935
# After iteration 7 : maximum power fraction remaining = 0.32250932584855846
# After iteration 8 : maximum power fraction remaining = 0.2903352263685305
# After iteration 9 : maximum power fraction remaining = 0.2647509278067714
# After iteration 10 : maximum power fraction remaining = 0.23917150444634547
# After iteration 11 : maximum power fraction remaining = 0.21788025799946084
# After iteration 12 : maximum power fraction remaining = 0.1972633881601088
# After iteration 13 : maximum power fraction remaining = 0.17957645878139095
# After iteration 14 : maximum power fraction remaining = 0.16281282210139958
# After iteration 15 : maximum power fraction remaining = 0.1481432600198912
# After iteration 16 : maximum power fraction remaining = 0.13443534420039344
# After iteration 17 : maximum power fraction remaining = 0.12228300193089472
# After iteration 18 : maximum power fraction remaining = 0.11103280382566622
# After iteration 19 : maximum power fraction remaining = 0.10097417423205204
# After iteration 20 : maximum power fraction remaining = 0.09171926189741515
# After iteration 21 : maximum power fraction remaining = 0.08339833862741017
# After iteration 22 : maximum power fraction remaining = 0.07577321582811204
# After iteration 23 : maximum power fraction remaining = 0.06889240104585698
# After iteration 24 : maximum power fraction remaining = 0.06260382757358889
# After iteration 25 : maximum power fraction remaining = 0.05691530951137815
# After iteration 26 : maximum power fraction remaining = 0.051725645425589245
# After iteration 27 : maximum power fraction remaining = 0.04702360591782512
# After iteration 28 : maximum power fraction remaining = 0.042738989902439406
# After iteration 29 : maximum power fraction remaining = 0.03885278424371628
# After iteration 30 : maximum power fraction remaining = 0.03531437957683089
# After iteration 31 : maximum power fraction remaining = 0.03210268777239644
# After iteration 32 : maximum power fraction remaining = 0.02917998262574064
# After iteration 33 : maximum power fraction remaining = 0.026525858601386627
# After iteration 34 : maximum power fraction remaining = 0.024111413341474423
# After iteration 35 : maximum power fraction remaining = 0.021918129322707085
# After iteration 36 : maximum power fraction remaining = 0.019923387859540505
# After iteration 37 : maximum power fraction remaining = 0.01811096516113693
# After iteration 38 : maximum power fraction remaining = 0.01646287574850684
# After iteration 39 : maximum power fraction remaining = 0.01496519883766559
# After iteration 40 : maximum power fraction remaining = 0.013603466392507535
# After iteration 41 : maximum power fraction remaining = 0.01236588769384691
# After iteration 42 : maximum power fraction remaining = 0.011240727790404161
# After iteration 43 : maximum power fraction remaining = 0.010218082775920897
# After iteration 44 : maximum power fraction remaining = 0.009288379212257435
# After iteration 1 : maximum power fraction remaining = 0.7684485778644032
# After iteration 2 : maximum power fraction remaining = 0.6498120326619525
# After iteration 3 : maximum power fraction remaining = 0.5556035597064046
# After iteration 4 : maximum power fraction remaining = 0.47594302345764516
# After iteration 5 : maximum power fraction remaining = 0.4072113153652765
# After iteration 6 : maximum power fraction remaining = 0.34809252840971433
# After iteration 7 : maximum power fraction remaining = 0.29738019985173136
# After iteration 8 : maximum power fraction remaining = 0.25397645350634224
# After iteration 9 : maximum power fraction remaining = 0.21686645646024627
# After iteration 10 : maximum power fraction remaining = 0.1851610063676129
# After iteration 11 : maximum power fraction remaining = 0.15808197091920137
# After iteration 12 : maximum power fraction remaining = 0.134959244983207
# After iteration 13 : maximum power fraction remaining = 0.11521681002977455
# After iteration 14 : maximum power fraction remaining = 0.0983615431079143
# After iteration 15 : maximum power fraction remaining = 0.08397166258319096
# After iteration 16 : maximum power fraction remaining = 0.07168677942670297
# After iteration 17 : maximum power fraction remaining = 0.06119906447612819
# After iteration 18 : maximum power fraction remaining = 0.05224565428556535
# After iteration 19 : maximum power fraction remaining = 0.04460210794436754
# After iteration 20 : maximum power fraction remaining = 0.03807680511252559
# After iteration 21 : maximum power fraction remaining = 0.03250615231987759
# After iteration 22 : maximum power fraction remaining = 0.027750486613114383
# After iteration 23 : maximum power fraction remaining = 0.023690576257086014
# After iteration 24 : maximum power fraction remaining = 0.020224632476291207
# After iteration 25 : maximum power fraction remaining = 0.017265757918946807
# After iteration 26 : maximum power fraction remaining = 0.01473976821159397
# After iteration 27 : maximum power fraction remaining = 0.012583332124789154
# After iteration 28 : maximum power fraction remaining = 0.010742383790091441
# After iteration 29 : maximum power fraction remaining = 0.009170767190112814

# %% [markdown]
# Finally, we use TMM to calculate the absorption in a structure with a planar front and planar rear,
# as a reference.

# %%
struc = tmm_structure([Layer(si("200um"), Si)], incidence=Air, transmission=Air)
options.coherent = False
options.coherency_list = ["i"]
RAT = tmm_structure.calculate(struc, options)

# %% [markdown]
# ## Plotting
#
# Plot everything together, including data from the reference paper for comparison:

# %%
palhf = sns.color_palette("hls", 4)

fig = plt.figure()
plt.plot(sim_fig6[:, 0], sim_fig6[:, 1],
    "--", color=palhf[0], label="OPTOS - rear grating (1)")
plt.plot(wavelengths * 1e9, RAT_fig6["A_bulk"][0],
    "-o", color=palhf[0], label="RayFlare - rear grating (1)", fillstyle="none")
plt.plot(sim_fig7[:, 0], sim_fig7[:, 1],
    "--", color=palhf[1], label="OPTOS - front pyramids (2)",)
plt.plot(wavelengths * 1e9, RAT_fig7["A_bulk"][0],
    "-o", color=palhf[1], label="RayFlare - front pyramids (2)", fillstyle="none")
plt.plot(sim_fig8[:, 0], sim_fig8[:, 1],
    "--", color=palhf[2], label="OPTOS - grating + pyramids (3)")
plt.plot(wavelengths * 1e9, RAT_fig8["A_bulk"][0],
    "-o", color=palhf[2],label="RayFlare - grating + pyramids (3)", fillstyle="none",)
plt.plot(wavelengths * 1e9, RAT["A_per_layer"][:, 0], "-k", label="Planar")
plt.legend(loc="lower left")
plt.xlabel("Wavelength (nm)")
plt.ylabel("Absorption in Si")
plt.xlim([900, 1200])
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# We can see good agreement between the reference values and our calculated values. The structure
# with rear grating also behaves identically to the planar TMM reference case at the short wavelengths
# where front surface reflection dominates the result, as expected. Clearly, the pyramids perform
# much better overall, giving a large boost in the absorption at long wavelengths and also reducing the reflection
# significantly at shorter wavelengths. Plotting reflection and transmission emphasises this:

# %%
fig = plt.figure()
plt.plot(wavelengths * 1e9,RAT_fig6["R"][0],
    "-o", color=palhf[0], label="RayFlare - rear grating (1)", fillstyle="none")
plt.plot(wavelengths * 1e9, RAT_fig7["R"][0],
    "-o", color=palhf[1], label="RayFlare - front pyramids (2)", fillstyle="none")
plt.plot(wavelengths * 1e9, RAT_fig8["R"][0],
    "-o", color=palhf[2], label="RayFlare - grating + pyramids (3)", fillstyle="none")

plt.plot(wavelengths * 1e9, RAT_fig6["T"][0], "--o", color=palhf[0])
plt.plot(wavelengths * 1e9, RAT_fig7["T"][0], "--o", color=palhf[1])
plt.plot(wavelengths * 1e9, RAT_fig8["T"][0], "--o", color=palhf[2])

# these are just to create the legend:
plt.plot(-1, 0, "k-o", label="R", fillstyle="none")
plt.plot(-1, 0, "k--o", label="T")

plt.legend()
plt.xlabel("Wavelength (nm)")
plt.ylabel("Reflected/transmitted fraction")
plt.xlim([900, 1200])
plt.ylim([0, 0.6])
plt.show()

# %% [markdown]
# ## Redistribution matrices
#
# Plot the redistribution matrix for the rear grating (summed over azimuthal angles) at 1100 nm:

# %%
theta_intv, phi_intv, angle_vector = make_angle_vector(
    options["n_theta_bins"], options["phi_symmetry"], options["c_azimuth"])

path = get_savepath(save_location='current', project_name=options.project_name)
sprs = load_npz(os.path.join(path, SC_fig6[2].name + "frontRT.npz"))

wl_to_plot = 1100e-9
wl_index = np.argmin(np.abs(wavelengths - wl_to_plot))

full = sprs[wl_index].todense()

summat = theta_summary(full, angle_vector, options["n_theta_bins"], "front")
summat_r = summat[: options["n_theta_bins"], :]
summat_r = summat_r.rename({ r"$\theta_{in}$": r"$\sin(\theta_{in})$",
        r"$\theta_{out}$": r"$\sin(\theta_{out})$"})

summat_r = summat_r.assign_coords({r"$\sin(\theta_{in})$": np.sin(summat_r.coords[r"$\sin(\theta_{in})$"]).data,
    r"$\sin(\theta_{out})$": np.sin(summat_r.coords[r"$\sin(\theta_{out})$"]).data})

palhf = sns.cubehelix_palette(256, start=0.5, rot=-0.9)
palhf.reverse()
seamap = mpl.colors.ListedColormap(palhf)

fig = plt.figure()
ax = plt.subplot(111)
ax = summat_r.plot.imshow(ax=ax, cmap=seamap, vmax=0.3)
plt.show()

# %% [markdown]
# ## Questions
#
# - If you can add only one of the textures (pyramids or a grating), which one is
#   better? Why?
# - Why do the structures with a front-surface texture have high reflection at long
#   wavelengths? The anti-reflection properties of pyramids (treated with ray optics)
#   are mostly independent of the wavelength, so why does apparent reflection increase'
#   near the bandgap of Si?
# - Can you explain any of the features present in the angular redistribution matrix
#   of the rear grating surface?
